# %%
import pandas as pd
import numpy as np

# %%
rfid=pd.read_excel('test1.xlsx',sheet_name='RFID data_2019.05.30 - 31')

# %%
rfid.head()
# Out:
#             Date/time  logId       RFID_gate    RFID_id  \
# 0 2019-05-30 01:11:51  15505    Főbejárat I.  100019790
# 1 2019-05-30 06:16:22  22814    Főbejárat I.  100013440
# 2 2019-05-30 06:16:29  22817    Főbejárat I.  100013440
# 3 2019-05-30 06:16:33  22824    Főbejárat I.  100013440
# 4 2019-05-30 06:34:49  23262  Főbejárat III.  100037900
#
#                       Area
# 0  Esemény területén kívül
# 1  Esemény területén kívül
# 2  Esemény területén kívül
# 3              Benti közös
# 4  Esemény területén kívül

# %%
#import seaborn as sns
#sns.distplot(rfid['Area'],kde=False)

# %%
a = rfid['Area'].value_counts()
a
# Out:
# Benti közös                66022
# Esemény területén kívül    33624
# Big Hall                   18483
# Secret Garden              16777
# Fun Factory                 8994
# Name: Area, dtype: int64

# %%
rfid.isna().sum()
# Out:
# Date/time    0
# logId        0
# RFID_gate    0
# RFID_id      0
# Area         0
# dtype: int64

# %%
rfid['Date/time']=pd.to_datetime(rfid['Date/time'])

# %%
rfid.head()
# Out:
#             Date/time  logId       RFID_gate    RFID_id  \
# 0 2019-05-30 01:11:51  15505    Főbejárat I.  100019790
# 1 2019-05-30 06:16:22  22814    Főbejárat I.  100013440
# 2 2019-05-30 06:16:29  22817    Főbejárat I.  100013440
# 3 2019-05-30 06:16:33  22824    Főbejárat I.  100013440
# 4 2019-05-30 06:34:49  23262  Főbejárat III.  100037900
#
#                       Area
# 0  Esemény területén kívül
# 1  Esemény területén kívül
# 2  Esemény területén kívül
# 3              Benti közös
# 4  Esemény területén kívül

# %%
agenda=pd.read_excel('test1.xlsx',sheet_name='Event agenda')

# %%
agenda.head()
# Out:
#    Session ID  Location ID  Track ID  \
# 0        8113          922      1029
# 1        8114          922      1030
# 2        8115          922      1031
# 3        8116          922      1032
# 4        8118          922      1033
#
#                                         Session Name         Format  \
# 0  STARY NIGHT How to reach the lifestyle of Haku...       MYTHBURN
# 1  DRAGONS OF THE UNIVERSE How to train your dragon?     ONE ON ONE
# 2  DREAMING OR NOT DREAMING Where are our dreams ...  TURNING POINT
# 3  THE SECRET OF THE FLYING CARPET Do you trust t...  TURNING POINT
# 4  JUNGLE VS CIVILIZATION What can be learnt from...     ONE ON ONE
#
#        Date Start        Date End       Speaker IDs    Speaker Names  \
# 0  30-05-19 10:00  30-05-19 10:30  2185817, 2185872     Timon, Pumba
# 1  30-05-19 10:35  30-05-19 11:00           2182426           Hiccup
# 2  30-05-19 11:00  30-05-19 11:40           2185889  Sleeping Beauty
# ...

# %%
agenda['Date Start']=pd.to_datetime(agenda['Date Start'])
agenda['Date End']=pd.to_datetime(agenda['Date End'])

# %%
agenda.head()
# Out:
#    Session ID  Location ID  Track ID  \
# 0        8113          922      1029
# 1        8114          922      1030
# 2        8115          922      1031
# 3        8116          922      1032
# 4        8118          922      1033
#
#                                         Session Name         Format  \
# 0  STARY NIGHT How to reach the lifestyle of Haku...       MYTHBURN
# 1  DRAGONS OF THE UNIVERSE How to train your dragon?     ONE ON ONE
# 2  DREAMING OR NOT DREAMING Where are our dreams ...  TURNING POINT
# 3  THE SECRET OF THE FLYING CARPET Do you trust t...  TURNING POINT
# 4  JUNGLE VS CIVILIZATION What can be learnt from...     ONE ON ONE
#
#            Date Start            Date End       Speaker IDs    Speaker Names  \
# 0 2019-05-30 10:00:00 2019-05-30 10:30:00  2185817, 2185872     Timon, Pumba
# 1 2019-05-30 10:35:00 2019-05-30 11:00:00           2182426           Hiccup
# 2 2019-05-30 11:00:00 2019-05-30 11:40:00           2185889  Sleeping Beauty
# ...

# %%
event_list = pd.DataFrame(columns=agenda['Session ID'].to_numpy())

event_list
# Out:
# Empty DataFrame
# Columns: [8113, 8114, 8115, 8116, 8118, 8119, 8120, 8121, 8122, 8139, 8140, 8141, 8158, 8159, 8143, 8144, 8145, 8146, 8180, 8123, 8124, 8126, 8128, 8161, 8129, 8130, 8131, 8132, 8133, 8135, 8136, 8148, 8149, 8150, 8151, 8178, 8160, 8152, 8153, 8154, 8155, 8872]
# Index: []
#
# [0 rows x 42 columns]

# %%
for index, row in rfid.iterrows():
    
    for i, row1 in agenda.iterrows():
        
        if row['Date/time']>=row1['Date Start'] and row['Date/time']<=row1['Date End'] and
        (row['Area']=='Big Hall' or row['Area']=='Secret Garden'):
            
            event_list=event_list.append({row1['Session ID']:row['RFID_id']}, ignore_index=True)

# %%
# !telegram-send "Готово!"

event_list
# Out:
#         8113  8114  8115  8116  8118  8119  8120  8121  8122  8139  ...  8149  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 5        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 6        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 7        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 9        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 10       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...

# %%
event_list.nunique().sort_values(ascending=False)
# Out:
# 8131    1108
# 8133    1085
# 8119    1077
# 8124    1053
# 8154    1049
# 8141    1009
# 8126     951
# 8145     841
# 8178     815
# 8115     764
# 8152     751
# 8161     750
# 8144     701
# 8872     685
# 8146     684
# 8132     677
# 8153     660
# 8136     651
# 8135     642
# 8128     621
# 8114     618
# 8149     611
# 8120     581
# 8139     581
# 8122     578
# 8113     565
# 8123     552
# 8180     530
# 8155     527
# 8143     512
# 8159     488
# 8158     466
# 8140     465
# 8121     435
# 8151     423
# 8160     362
# 8150     256
# 8118     253
# 8130     253
# 8148     198
# 8116       0
# 8129       0
# dtype: int64

# %%
agenda[agenda['Session ID']==8131]
# Out:
#     Session ID  Location ID  Track ID  \
# 26        8131          923      1030
#
#                                          Session Name      Format  \
# 26  WAR OF THE MUSIC How to preserve our music her...  CHOSEN ONE
#
#             Date Start            Date End Speaker IDs Speaker Names  \
# 26 2019-05-30 14:15:00 2019-05-30 14:50:00     2187309        Miguel
#
#                   Track       Location
# 26  FUTURE OF HUMANKIND  Secret Garden

# %%
rfid['Date/time'].sort_values(ascending=True)
# Out:
# 0        2019-05-30 01:11:51
# 1        2019-05-30 06:16:22
# 2        2019-05-30 06:16:29
# 3        2019-05-30 06:16:33
# 4        2019-05-30 06:34:49
# 5        2019-05-30 06:34:54
# 6        2019-05-30 06:34:58
# 7        2019-05-30 06:35:00
# 8        2019-05-30 06:35:02
# 9        2019-05-30 06:35:05
# 10       2019-05-30 06:35:08
# 11       2019-05-30 06:35:09
# 12       2019-05-30 06:35:09
# 13       2019-05-30 06:35:17
# 15       2019-05-30 06:35:24
# 14       2019-05-30 06:35:24
# 16       2019-05-30 06:35:25
# 17       2019-05-30 06:35:25
# 18       2019-05-30 06:35:26
# 19       2019-05-30 06:35:27
# 20       2019-05-30 06:35:30
# 21       2019-05-30 06:35:35
# 22       2019-05-30 06:35:36
# 23       2019-05-30 06:35:40
# 24       2019-05-30 06:35:41
# 25       2019-05-30 06:35:42
# 26       2019-05-30 06:35:43
# 27       2019-05-30 06:35:48
# 28       2019-05-30 06:35:52
# 29       2019-05-30 06:36:01
#                  ...
# 143870   2019-05-31 19:40:52
# ...

# %%
maxi=0
time='2019-05-30 01:11:51'
inside=[]

for index, row in rfid.iterrows():
    
    if row['Area'] != 'Esemény területén kívül':
        
        if row['RFID_id'] in inside:
            
            if len(inside) > maxi:
                
                maxi = len(inside)
                time = row['Date/time']
                
        else:

            inside.append(row['RFID_id'])
    else:
        
        if row['RFID_id'] in inside:
            
            inside.remove(row['RFID_id'])
        
print(maxi,time)
# Out:
# 1870 2019-05-31 15:39:15

# %%
format_list = pd.DataFrame(columns=['MYTHBURN','ONE ON ONE','TURNING POINT','BATTLE OF MINDS','CHOSEN ONE','MINDBLOWN','ROUNDTABLE'])
format_list
# Out:
# Empty DataFrame
# Columns: [MYTHBURN, ONE ON ONE, TURNING POINT, BATTLE OF MINDS, CHOSEN ONE, MINDBLOWN, ROUNDTABLE]
# Index: []

# %%
for index, row in rfid.iterrows():
    
    for i, row1 in agenda.iterrows():
        
        if row['Date/time']>=row1['Date Start'] and row['Date/time']<=row1['Date End'] and 
        (row['Area']=='Big Hall' or row['Area']=='Secret Garden'):
            
            format_list=format_list.append({row1['Format']:row['RFID_id']}, ignore_index=True)

# %%
# !telegram-send "Готово!"

# %%
format_list.nunique().sort_values(ascending=False)
# Out:
# TURNING POINT      2552
# BATTLE OF MINDS    1471
# MYTHBURN           1307
# CHOSEN ONE         1089
# MINDBLOWN          1026
# ROUNDTABLE          868
# ONE ON ONE          787
# dtype: int64
